# %%
import pandas as pd

# %%
df = pd.read_excel("/home/achint/Downloads/OpTransactionHistoryTpr18-03-2021.xls", skiprows=12,
                  names=None)

# %%
df.head()
# Out:
#    Unnamed: 0  S No.  Value Date Transaction Date Cheque Number  \
# 0         NaN    1.0  01/04/2020       02/04/2020             -
# 1         NaN    2.0  04/04/2020       04/04/2020             -
# 2         NaN    3.0  05/04/2020       06/04/2020             -
# 3         NaN    4.0  05/04/2020       06/04/2020             -
# 4         NaN    5.0  06/04/2020       06/04/2020             -
#
#                                  Transaction Remarks  \
# 0  VIN/Amazon Pay /202004011336/009208696496/    ...
# 1  VPS REF Amazon Pay                            ...
# 2  UPI/009601418323/EarlySalary/earlysalary.raz/H...
# 3  BIL/001961727407/ICICI BANK CREDIT CA/43755171...
# 4  UPI/009722753097/SPOTIFY/billdesk@hdfcba/HDFC ...
#
#    Withdrawal Amount (INR )  Deposit Amount (INR )  Balance (INR )
# 0                       2.0                    0.0        82661.66
# 1                       0.0                    2.0        82663.66
# ...

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df.head()
# Out:
#    S No.  Value Date Transaction Date Cheque Number  \
# 0    1.0  01/04/2020       02/04/2020             -
# 1    2.0  04/04/2020       04/04/2020             -
# 2    3.0  05/04/2020       06/04/2020             -
# 3    4.0  05/04/2020       06/04/2020             -
# 4    5.0  06/04/2020       06/04/2020             -
#
#                                  Transaction Remarks  \
# 0  VIN/Amazon Pay /202004011336/009208696496/    ...
# 1  VPS REF Amazon Pay                            ...
# 2  UPI/009601418323/EarlySalary/earlysalary.raz/H...
# 3  BIL/001961727407/ICICI BANK CREDIT CA/43755171...
# 4  UPI/009722753097/SPOTIFY/billdesk@hdfcba/HDFC ...
#
#    Withdrawal Amount (INR )  Deposit Amount (INR )  Balance (INR )
# 0                       2.0                    0.0        82661.66
# 1                       0.0                    2.0        82663.66
# 2                    6762.0                    0.0        75901.66
# ...

# %%
df.tail()
# Out:
#      S No.  Value Date Transaction Date Cheque Number  \
# 716  713.0  14/03/2021       15/03/2021             -
# 717  714.0  14/03/2021       15/03/2021             -
# 718  715.0  15/03/2021       15/03/2021             -
# 719  716.0  16/03/2021       16/03/2021             -
# 720  717.0  17/03/2021       17/03/2021             -
#
#                                    Transaction Remarks  \
# 716  UPI/107317664851/Oid202103142256/paytm-2733624...
# 717  UPI/107317667595/Oid202103142256/paytm-2733624...
# 718  UPI/107415096989/UPI/nutalapatideepa/Paytm Pay...
# 719  UPI/107562898838/Oid202103162021/paytm-4790675...
# 720  UPI/107686170098/NA/Q35487011@ybl/Axis Bank Lt...
#
#      Withdrawal Amount (INR )  Deposit Amount (INR )  Balance (INR )
# 716                      10.0                    0.0        16943.33
# 717                       8.0                    0.0        16935.33
# 718                     500.0                    0.0        16435.33
# ...

# %%
columns = df.columns
columns
# Out:
# Index(['S No.', 'Value Date', 'Transaction Date', 'Cheque Number',
#        'Transaction Remarks', 'Withdrawal Amount (INR )',
#        'Deposit Amount (INR )', 'Balance (INR )'],
#       dtype='object')

# %%
columns_map = {"S No.":"sno",
              "Value Date": "value_date",
              columns[2]:"trans_date",
              columns[3]:"cheq_no",
              columns[4]:"text",
              columns[5]:"with_amount",
              columns[6]:"dep_amount", columns[7]:"balance"}
df.rename(columns=columns_map, inplace=True)

# %%
df.head()
# Out:
#    sno  value_date  trans_date cheq_no  \
# 0  1.0  01/04/2020  02/04/2020       -
# 1  2.0  04/04/2020  04/04/2020       -
# 2  3.0  05/04/2020  06/04/2020       -
# 3  4.0  05/04/2020  06/04/2020       -
# 4  5.0  06/04/2020  06/04/2020       -
#
#                                                 text  with_amount  dep_amount  \
# 0  VIN/Amazon Pay /202004011336/009208696496/    ...          2.0         0.0
# 1  VPS REF Amazon Pay                            ...          0.0         2.0
# 2  UPI/009601418323/EarlySalary/earlysalary.raz/H...       6762.0         0.0
# 3  BIL/001961727407/ICICI BANK CREDIT CA/43755171...      35000.0         0.0
# 4  UPI/009722753097/SPOTIFY/billdesk@hdfcba/HDFC ...        129.0         0.0
#
#     balance
# 0  82661.66
# 1  82663.66
# 2  75901.66
# 3  40901.66
# 4  40772.66

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 721 entries, 0 to 720
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sno          717 non-null    float64
#  1   value_date   717 non-null    object
#  2   trans_date   717 non-null    object
#  3   cheq_no      717 non-null    object
#  4   text         721 non-null    object
#  5   with_amount  717 non-null    float64
#  6   dep_amount   717 non-null    float64
#  7   balance      717 non-null    float64
# dtypes: float64(4), object(4)
# memory usage: 45.2+ KB

# %%
df.describe()
# Out:
#               sno   with_amount    dep_amount       balance
# count  717.000000    717.000000    717.000000    717.000000
# mean   359.000000   1171.708159   1078.830432  21672.008703
# std    207.124359   3897.584171   7617.474997  19591.963482
# min      1.000000      0.000000      0.000000     26.330000
# 25%    180.000000     28.000000      0.000000   2856.910000
# 50%    359.000000     88.000000      0.000000  17490.990000
# 75%    538.000000    400.000000      0.000000  35942.350000
# max    717.000000  35000.000000  71652.000000  82663.660000

# %%
df['with_amount'].plot.hist()

# %%
df['text'].values[:10]
# Out:
# array(['VIN/Amazon Pay /202004011336/009208696496/        ',
#        'VPS REF Amazon Pay                                ',
#        'UPI/009601418323/EarlySalary/earlysalary.raz/HDFC ',
#        'BIL/001961727407/ICICI BANK CREDIT CA/437551711005',
#        'UPI/009722753097/SPOTIFY/billdesk@hdfcba/HDFC BANK',
#        'MMT/IMPS/009921822103/NA/EXTRA/BKID0008403        ',
#        'UPI/009958232887/Oid10710811601@/payide@paytm/Payt',
#        'UPI/010612458880/credit card bil/credclub@icici/IC',
#        'UPI/010614313537/Oid202004152020/paytm-14774318@/P',
#        'NFS/AECN6770/CASH WDL/15-04-20                    '], dtype=object)

# %%
df['text_pre'] = df['text'].str.replace('/', ' ')

# %%
df[df['text'].str.contains(r'.*/[0-9]+/*')]
# Out:
#        sno  value_date  trans_date cheq_no  \
# 0      1.0  01/04/2020  02/04/2020       -
# 2      3.0  05/04/2020  06/04/2020       -
# 3      4.0  05/04/2020  06/04/2020       -
# 4      5.0  06/04/2020  06/04/2020       -
# 5      6.0  08/04/2020  08/04/2020       -
# ..     ...         ...         ...     ...
# 716  713.0  14/03/2021  15/03/2021       -
# 717  714.0  14/03/2021  15/03/2021       -
# 718  715.0  15/03/2021  15/03/2021       -
# 719  716.0  16/03/2021  16/03/2021       -
# 720  717.0  17/03/2021  17/03/2021       -
#
#                                                   text  with_amount  \
# 0    VIN/Amazon Pay /202004011336/009208696496/    ...          2.0
# 2    UPI/009601418323/EarlySalary/earlysalary.raz/H...       6762.0
# 3    BIL/001961727407/ICICI BANK CREDIT CA/43755171...      35000.0
# 4    UPI/009722753097/SPOTIFY/billdesk@hdfcba/HDFC ...        129.0
# 5    MMT/IMPS/009921822103/NA/EXTRA/BKID0008403    ...       2000.0
# ...

# %%
for a in text[:10]:
    print(a, a.replace('/', ' '))
# Out:
# VIN/Amazon Pay /202004011336/009208696496/         VIN Amazon Pay  202004011336 009208696496
# VPS REF Amazon Pay                                 VPS REF Amazon Pay
# UPI/009601418323/EarlySalary/earlysalary.raz/HDFC  UPI 009601418323 EarlySalary earlysalary.raz HDFC
# BIL/001961727407/ICICI BANK CREDIT CA/437551711005 BIL 001961727407 ICICI BANK CREDIT CA 437551711005
# UPI/009722753097/SPOTIFY/billdesk@hdfcba/HDFC BANK UPI 009722753097 SPOTIFY billdesk@hdfcba HDFC BANK
# MMT/IMPS/009921822103/NA/EXTRA/BKID0008403         MMT IMPS 009921822103 NA EXTRA BKID0008403
# UPI/009958232887/Oid10710811601@/payide@paytm/Payt UPI 009958232887 Oid10710811601@ payide@paytm Payt
# UPI/010612458880/credit card bil/credclub@icici/IC UPI 010612458880 credit card bil credclub@icici IC
# UPI/010614313537/Oid202004152020/paytm-14774318@/P UPI 010614313537 Oid202004152020 paytm-14774318@ P
# NFS/AECN6770/CASH WDL/15-04-20                     NFS AECN6770 CASH WDL 15-04-20

# %%
df[df['text'].str.contains('zomato')]['with_amount'].sum()
# Out:
# 7006.280000000002
