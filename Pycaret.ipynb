# %%
import pandas as pd

# %%
import pycaret
from pycaret.classification import *
print(pycaret.__version__)
# Out:
# 2.2.0
# /home/achint/Raghava/pm4py_sources/venv/lib/python3.6/site-packages/google/colab/data_table.py:30: UserWarning:
#
# IPython.utils.traitlets has moved to a top-level traitlets package.

# %%
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/sonar.csv'

df = pd.read_csv(url, header=None)
print(df.shape)
# Out:
# (208, 61)

# %%
df.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# 3  0.0040  0.0117   R
# 4  0.0107  0.0094   R
#
# [5 rows x 61 columns]

# %%
n_cols = df.shape[1]
df.columns = [str(i) for i in range(n_cols)]

# %%
df.head()
# Out:
#         0       1       2       3       4       5       6       7       8  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#         9  ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# 3  0.0040  0.0117   R
# 4  0.0107  0.0094   R
#
# [5 rows x 61 columns]

# %%
grid = setup(data=df, target=df.columns[-1], html=False, silent=True, verbose=False)

# %%
best = compare_models()
# Out:
#                   Model  Accuracy     AUC  Recall   Prec.     F1  Kappa  \
# lr  Logistic Regression    0.7862  0.8402  0.6976  0.8267  0.745  0.565
#
#        MCC  TT (Sec)
# lr  0.5801     0.245
#                       Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# lr      Logistic Regression    0.7862  0.8402  0.6976  0.8267  0.7450  0.5650
# knn  K Neighbors Classifier    0.7533  0.8635  0.5929  0.8181  0.6784  0.4905
#
#         MCC  TT (Sec)
# lr   0.5801     0.245
# knn  0.5113     0.056
#                       Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# lr      Logistic Regression    0.7862  0.8402  0.6976  0.8267  0.7450  0.5650
# knn  K Neighbors Classifier    0.7533  0.8635  0.5929  0.8181  0.6784  0.4905
# nb              Naive Bayes    0.6829  0.7886  0.8048  0.6132  0.6862  0.3765
#
#         MCC  TT (Sec)
# lr   0.5801     0.245
# knn  0.5113     0.056
# nb   0.4041     0.009
#                         Model  Accuracy     AUC  Recall   Prec.      F1  \
# lr        Logistic Regression    0.7862  0.8402  0.6976  0.8267  0.7450
# dt   Decision Tree Classifier    0.7729  0.7714  0.7429  0.7654  0.7481
# knn    K Neighbors Classifier    0.7533  0.8635  0.5929  0.8181  0.6784
# nb                Naive Bayes    0.6829  0.7886  0.8048  0.6132  0.6862
#
#       Kappa     MCC  TT (Sec)
# lr   0.5650  0.5801     0.245
# dt   0.5438  0.5485     0.008
# knn  0.4905  0.5113     0.056
# nb   0.3765  0.4041     0.009
#                         Model  Accuracy     AUC  Recall   Prec.      F1  \
# lr        Logistic Regression    0.7862  0.8402  0.6976  0.8267  0.7450
# svm       SVM - Linear Kernel    0.7795  0.0000  0.6333  0.8738  0.7070
# dt   Decision Tree Classifier    0.7729  0.7714  0.7429  0.7654  0.7481
# knn    K Neighbors Classifier    0.7533  0.8635  0.5929  0.8181  0.6784
# nb                Naive Bayes    0.6829  0.7886  0.8048  0.6132  0.6862
#
#       Kappa     MCC  TT (Sec)
# lr   0.5650  0.5801     0.245
# svm  0.5425  0.5834     0.007
# dt   0.5438  0.5485     0.008
# knn  0.4905  0.5113     0.056
# nb   0.3765  0.4041     0.009
#                           Model  Accuracy     AUC  Recall   Prec.      F1  \
# lr          Logistic Regression    0.7862  0.8402  0.6976  0.8267  0.7450
# ridge          Ridge Classifier    0.7852  0.0000  0.7119  0.8101  0.7472
# svm         SVM - Linear Kernel    0.7795  0.0000  0.6333  0.8738  0.7070
# dt     Decision Tree Classifier    0.7729  0.7714  0.7429  0.7654  0.7481
# knn      K Neighbors Classifier    0.7533  0.8635  0.5929  0.8181  0.6784
# nb                  Naive Bayes    0.6829  0.7886  0.8048  0.6132  0.6862
#
#         Kappa     MCC  TT (Sec)
# lr     0.5650  0.5801     0.245
# ridge  0.5643  0.5778     0.008
# svm    0.5425  0.5834     0.007
# dt     0.5438  0.5485     0.008
# knn    0.4905  0.5113     0.056
# nb     0.3765  0.4041     0.009
#                           Model  Accuracy     AUC  Recall   Prec.      F1  \
# rf     Random Forest Classifier    0.8010  0.9020  0.6381  0.9165  0.7110
# lr          Logistic Regression    0.7862  0.8402  0.6976  0.8267  0.7450
# ridge          Ridge Classifier    0.7852  0.0000  0.7119  0.8101  0.7472
# svm         SVM - Linear Kernel    0.7795  0.0000  0.6333  0.8738  0.7070
# dt     Decision Tree Classifier    0.7729  0.7714  0.7429  0.7654  0.7481
# knn      K Neighbors Classifier    0.7533  0.8635  0.5929  0.8181  0.6784
# nb                  Naive Bayes    0.6829  0.7886  0.8048  0.6132  0.6862
#
#         Kappa     MCC  TT (Sec)
# rf     0.5840  0.6245     0.200
# lr     0.5650  0.5801     0.245
# ridge  0.5643  0.5778     0.008
# svm    0.5425  0.5834     0.007
# dt     0.5438  0.5485     0.008
# knn    0.4905  0.5113     0.056
# nb     0.3765  0.4041     0.009
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# rf            Random Forest Classifier    0.8010  0.9020  0.6381  0.9165
# lr                 Logistic Regression    0.7862  0.8402  0.6976  0.8267
# ridge                 Ridge Classifier    0.7852  0.0000  0.7119  0.8101
# svm                SVM - Linear Kernel    0.7795  0.0000  0.6333  0.8738
# dt            Decision Tree Classifier    0.7729  0.7714  0.7429  0.7654
# knn             K Neighbors Classifier    0.7533  0.8635  0.5929  0.8181
# nb                         Naive Bayes    0.6829  0.7886  0.8048  0.6132
# qda    Quadratic Discriminant Analysis    0.5452  0.5000  0.0000  0.0000
#
#            F1   Kappa     MCC  TT (Sec)
# rf     0.7110  0.5840  0.6245     0.200
# lr     0.7450  0.5650  0.5801     0.245
# ridge  0.7472  0.5643  0.5778     0.008
# svm    0.7070  0.5425  0.5834     0.007
# dt     0.7481  0.5438  0.5485     0.008
# knn    0.6784  0.4905  0.5113     0.056
# nb     0.6862  0.3765  0.4041     0.009
# qda    0.0000  0.0000  0.0000     0.008
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# ada               Ada Boost Classifier    0.8281  0.8893  0.8048  0.8223
# rf            Random Forest Classifier    0.8010  0.9020  0.6381  0.9165
# lr                 Logistic Regression    0.7862  0.8402  0.6976  0.8267
# ridge                 Ridge Classifier    0.7852  0.0000  0.7119  0.8101
# svm                SVM - Linear Kernel    0.7795  0.0000  0.6333  0.8738
# dt            Decision Tree Classifier    0.7729  0.7714  0.7429  0.7654
# knn             K Neighbors Classifier    0.7533  0.8635  0.5929  0.8181
# nb                         Naive Bayes    0.6829  0.7886  0.8048  0.6132
# qda    Quadratic Discriminant Analysis    0.5452  0.5000  0.0000  0.0000
#
#            F1   Kappa     MCC  TT (Sec)
# ada    0.8060  0.6526  0.6622     0.039
# rf     0.7110  0.5840  0.6245     0.200
# lr     0.7450  0.5650  0.5801     0.245
# ridge  0.7472  0.5643  0.5778     0.008
# svm    0.7070  0.5425  0.5834     0.007
# dt     0.7481  0.5438  0.5485     0.008
# knn    0.6784  0.4905  0.5113     0.056
# nb     0.6862  0.3765  0.4041     0.009
# qda    0.0000  0.0000  0.0000     0.008
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# gbc       Gradient Boosting Classifier    0.8433  0.9119  0.7762  0.8713
# ada               Ada Boost Classifier    0.8281  0.8893  0.8048  0.8223
# rf            Random Forest Classifier    0.8010  0.9020  0.6381  0.9165
# lr                 Logistic Regression    0.7862  0.8402  0.6976  0.8267
# ridge                 Ridge Classifier    0.7852  0.0000  0.7119  0.8101
# svm                SVM - Linear Kernel    0.7795  0.0000  0.6333  0.8738
# dt            Decision Tree Classifier    0.7729  0.7714  0.7429  0.7654
# knn             K Neighbors Classifier    0.7533  0.8635  0.5929  0.8181
# nb                         Naive Bayes    0.6829  0.7886  0.8048  0.6132
# qda    Quadratic Discriminant Analysis    0.5452  0.5000  0.0000  0.0000
#
#            F1   Kappa     MCC  TT (Sec)
# gbc    0.8076  0.6795  0.6941     0.062
# ada    0.8060  0.6526  0.6622     0.039
# rf     0.7110  0.5840  0.6245     0.200
# lr     0.7450  0.5650  0.5801     0.245
# ridge  0.7472  0.5643  0.5778     0.008
# svm    0.7070  0.5425  0.5834     0.007
# dt     0.7481  0.5438  0.5485     0.008
# knn    0.6784  0.4905  0.5113     0.056
# nb     0.6862  0.3765  0.4041     0.009
# qda    0.0000  0.0000  0.0000     0.008
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# gbc       Gradient Boosting Classifier    0.8433  0.9119  0.7762  0.8713
# ada               Ada Boost Classifier    0.8281  0.8893  0.8048  0.8223
# rf            Random Forest Classifier    0.8010  0.9020  0.6381  0.9165
# lr                 Logistic Regression    0.7862  0.8402  0.6976  0.8267
# ridge                 Ridge Classifier    0.7852  0.0000  0.7119  0.8101
# svm                SVM - Linear Kernel    0.7795  0.0000  0.6333  0.8738
# dt            Decision Tree Classifier    0.7729  0.7714  0.7429  0.7654
# knn             K Neighbors Classifier    0.7533  0.8635  0.5929  0.8181
# lda       Linear Discriminant Analysis    0.7090  0.7621  0.6810  0.7285
# nb                         Naive Bayes    0.6829  0.7886  0.8048  0.6132
# qda    Quadratic Discriminant Analysis    0.5452  0.5000  0.0000  0.0000
#
#            F1   Kappa     MCC  TT (Sec)
# gbc    0.8076  0.6795  0.6941     0.062
# ada    0.8060  0.6526  0.6622     0.039
# rf     0.7110  0.5840  0.6245     0.200
# lr     0.7450  0.5650  0.5801     0.245
# ridge  0.7472  0.5643  0.5778     0.008
# svm    0.7070  0.5425  0.5834     0.007
# dt     0.7481  0.5438  0.5485     0.008
# knn    0.6784  0.4905  0.5113     0.056
# lda    0.6891  0.4210  0.4324     0.009
# nb     0.6862  0.3765  0.4041     0.009
# qda    0.0000  0.0000  0.0000     0.008
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# et              Extra Trees Classifier    0.8481  0.9451  0.7738  0.8806
# gbc       Gradient Boosting Classifier    0.8433  0.9119  0.7762  0.8713
# ada               Ada Boost Classifier    0.8281  0.8893  0.8048  0.8223
# rf            Random Forest Classifier    0.8010  0.9020  0.6381  0.9165
# lr                 Logistic Regression    0.7862  0.8402  0.6976  0.8267
# ridge                 Ridge Classifier    0.7852  0.0000  0.7119  0.8101
# svm                SVM - Linear Kernel    0.7795  0.0000  0.6333  0.8738
# dt            Decision Tree Classifier    0.7729  0.7714  0.7429  0.7654
# knn             K Neighbors Classifier    0.7533  0.8635  0.5929  0.8181
# lda       Linear Discriminant Analysis    0.7090  0.7621  0.6810  0.7285
# nb                         Naive Bayes    0.6829  0.7886  0.8048  0.6132
# qda    Quadratic Discriminant Analysis    0.5452  0.5000  0.0000  0.0000
#
#            F1   Kappa     MCC  TT (Sec)
# et     0.8131  0.6885  0.7036     0.181
# gbc    0.8076  0.6795  0.6941     0.062
# ada    0.8060  0.6526  0.6622     0.039
# rf     0.7110  0.5840  0.6245     0.200
# lr     0.7450  0.5650  0.5801     0.245
# ridge  0.7472  0.5643  0.5778     0.008
# svm    0.7070  0.5425  0.5834     0.007
# dt     0.7481  0.5438  0.5485     0.008
# knn    0.6784  0.4905  0.5113     0.056
# lda    0.6891  0.4210  0.4324     0.009
# nb     0.6862  0.3765  0.4041     0.009
# qda    0.0000  0.0000  0.0000     0.008
#                                    Model  Accuracy     AUC  Recall   Prec.  \
# et                Extra Trees Classifier    0.8481  0.9451  0.7738  0.8806
# gbc         Gradient Boosting Classifier    0.8433  0.9119  0.7762  0.8713
# xgboost        Extreme Gradient Boosting    0.8419  0.9238  0.7762  0.8699
# ada                 Ada Boost Classifier    0.8281  0.8893  0.8048  0.8223
# rf              Random Forest Classifier    0.8010  0.9020  0.6381  0.9165
# lr                   Logistic Regression    0.7862  0.8402  0.6976  0.8267
# ridge                   Ridge Classifier    0.7852  0.0000  0.7119  0.8101
# svm                  SVM - Linear Kernel    0.7795  0.0000  0.6333  0.8738
# dt              Decision Tree Classifier    0.7729  0.7714  0.7429  0.7654
# knn               K Neighbors Classifier    0.7533  0.8635  0.5929  0.8181
# lda         Linear Discriminant Analysis    0.7090  0.7621  0.6810  0.7285
# nb                           Naive Bayes    0.6829  0.7886  0.8048  0.6132
# qda      Quadratic Discriminant Analysis    0.5452  0.5000  0.0000  0.0000
#
#              F1   Kappa     MCC  TT (Sec)
# et       0.8131  0.6885  0.7036     0.181
# gbc      0.8076  0.6795  0.6941     0.062
# xgboost  0.8072  0.6773  0.6920     0.076
# ada      0.8060  0.6526  0.6622     0.039
# rf       0.7110  0.5840  0.6245     0.200
# lr       0.7450  0.5650  0.5801     0.245
# ridge    0.7472  0.5643  0.5778     0.008
# svm      0.7070  0.5425  0.5834     0.007
# dt       0.7481  0.5438  0.5485     0.008
# knn      0.6784  0.4905  0.5113     0.056
# lda      0.6891  0.4210  0.4324     0.009
# nb       0.6862  0.3765  0.4041     0.009
# qda      0.0000  0.0000  0.0000     0.008
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# et                 Extra Trees Classifier    0.8481  0.9451  0.7738  0.8806
# gbc          Gradient Boosting Classifier    0.8433  0.9119  0.7762  0.8713
# xgboost         Extreme Gradient Boosting    0.8419  0.9238  0.7762  0.8699
# lightgbm  Light Gradient Boosting Machine    0.8414  0.8997  0.7929  0.8651
# ada                  Ada Boost Classifier    0.8281  0.8893  0.8048  0.8223
# rf               Random Forest Classifier    0.8010  0.9020  0.6381  0.9165
# lr                    Logistic Regression    0.7862  0.8402  0.6976  0.8267
# ridge                    Ridge Classifier    0.7852  0.0000  0.7119  0.8101
# svm                   SVM - Linear Kernel    0.7795  0.0000  0.6333  0.8738
# dt               Decision Tree Classifier    0.7729  0.7714  0.7429  0.7654
# knn                K Neighbors Classifier    0.7533  0.8635  0.5929  0.8181
# lda          Linear Discriminant Analysis    0.7090  0.7621  0.6810  0.7285
# nb                            Naive Bayes    0.6829  0.7886  0.8048  0.6132
# qda       Quadratic Discriminant Analysis    0.5452  0.5000  0.0000  0.0000
#
#               F1   Kappa     MCC  TT (Sec)
# et        0.8131  0.6885  0.7036     0.181
# gbc       0.8076  0.6795  0.6941     0.062
# xgboost   0.8072  0.6773  0.6920     0.076
# lightgbm  0.8108  0.6786  0.6961     0.014
# ada       0.8060  0.6526  0.6622     0.039
# rf        0.7110  0.5840  0.6245     0.200
# lr        0.7450  0.5650  0.5801     0.245
# ridge     0.7472  0.5643  0.5778     0.008
# svm       0.7070  0.5425  0.5834     0.007
# dt        0.7481  0.5438  0.5485     0.008
# knn       0.6784  0.4905  0.5113     0.056
# lda       0.6891  0.4210  0.4324     0.009
# nb        0.6862  0.3765  0.4041     0.009
# qda       0.0000  0.0000  0.0000     0.008
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# et                 Extra Trees Classifier    0.8481  0.9451  0.7738  0.8806
# gbc          Gradient Boosting Classifier    0.8433  0.9119  0.7762  0.8713
# xgboost         Extreme Gradient Boosting    0.8419  0.9238  0.7762  0.8699
# lightgbm  Light Gradient Boosting Machine    0.8414  0.8997  0.7929  0.8651
# catboost              CatBoost Classifier    0.8357  0.9289  0.7310  0.8967
# ada                  Ada Boost Classifier    0.8281  0.8893  0.8048  0.8223
# rf               Random Forest Classifier    0.8010  0.9020  0.6381  0.9165
# lr                    Logistic Regression    0.7862  0.8402  0.6976  0.8267
# ridge                    Ridge Classifier    0.7852  0.0000  0.7119  0.8101
# svm                   SVM - Linear Kernel    0.7795  0.0000  0.6333  0.8738
# dt               Decision Tree Classifier    0.7729  0.7714  0.7429  0.7654
# knn                K Neighbors Classifier    0.7533  0.8635  0.5929  0.8181
# lda          Linear Discriminant Analysis    0.7090  0.7621  0.6810  0.7285
# nb                            Naive Bayes    0.6829  0.7886  0.8048  0.6132
# qda       Quadratic Discriminant Analysis    0.5452  0.5000  0.0000  0.0000
#
#               F1   Kappa     MCC  TT (Sec)
# et        0.8131  0.6885  0.7036     0.181
# gbc       0.8076  0.6795  0.6941     0.062
# xgboost   0.8072  0.6773  0.6920     0.076
# lightgbm  0.8108  0.6786  0.6961     0.014
# catboost  0.7838  0.6618  0.6846     2.823
# ada       0.8060  0.6526  0.6622     0.039
# rf        0.7110  0.5840  0.6245     0.200
# lr        0.7450  0.5650  0.5801     0.245
# ridge     0.7472  0.5643  0.5778     0.008
# svm       0.7070  0.5425  0.5834     0.007
# dt        0.7481  0.5438  0.5485     0.008
# knn       0.6784  0.4905  0.5113     0.056
# lda       0.6891  0.4210  0.4324     0.009
# nb        0.6862  0.3765  0.4041     0.009
# qda       0.0000  0.0000  0.0000     0.008
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# et                 Extra Trees Classifier    0.8481  0.9451  0.7738  0.8806
# gbc          Gradient Boosting Classifier    0.8433  0.9119  0.7762  0.8713
# xgboost         Extreme Gradient Boosting    0.8419  0.9238  0.7762  0.8699
# lightgbm  Light Gradient Boosting Machine    0.8414  0.8997  0.7929  0.8651
# catboost              CatBoost Classifier    0.8357  0.9289  0.7310  0.8967
# ada                  Ada Boost Classifier    0.8281  0.8893  0.8048  0.8223
# rf               Random Forest Classifier    0.8010  0.9020  0.6381  0.9165
# lr                    Logistic Regression    0.7862  0.8402  0.6976  0.8267
# ridge                    Ridge Classifier    0.7852  0.0000  0.7119  0.8101
# svm                   SVM - Linear Kernel    0.7795  0.0000  0.6333  0.8738
# dt               Decision Tree Classifier    0.7729  0.7714  0.7429  0.7654
# knn                K Neighbors Classifier    0.7533  0.8635  0.5929  0.8181
# lda          Linear Discriminant Analysis    0.7090  0.7621  0.6810  0.7285
# nb                            Naive Bayes    0.6829  0.7886  0.8048  0.6132
# qda       Quadratic Discriminant Analysis    0.5452  0.5000  0.0000  0.0000
#
#               F1   Kappa     MCC  TT (Sec)
# et        0.8131  0.6885  0.7036     0.181
# gbc       0.8076  0.6795  0.6941     0.062
# xgboost   0.8072  0.6773  0.6920     0.076
# lightgbm  0.8108  0.6786  0.6961     0.014
# catboost  0.7838  0.6618  0.6846     2.823
# ada       0.8060  0.6526  0.6622     0.039
# rf        0.7110  0.5840  0.6245     0.200
# lr        0.7450  0.5650  0.5801     0.245
# ridge     0.7472  0.5643  0.5778     0.008
# svm       0.7070  0.5425  0.5834     0.007
# dt        0.7481  0.5438  0.5485     0.008
# knn       0.6784  0.4905  0.5113     0.056
# lda       0.6891  0.4210  0.4324     0.009
# nb        0.6862  0.3765  0.4041     0.009
# qda       0.0000  0.0000  0.0000     0.008

# %%
best
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=5072, verbose=0,
#                      warm_start=False)

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
best = tune_model(ExtraTreesClassifier(), n_iter=200, choose_better = True)
# Out:
# Fitting 10 folds for each of 200 candidates, totalling 2000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 200 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-1)]: Done 450 tasks      | elapsed:   26.1s
# [Parallel(n_jobs=-1)]: Done 800 tasks      | elapsed:   51.1s
# [Parallel(n_jobs=-1)]: Done 1250 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 1800 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 2000 out of 2000 | elapsed:  2.6min finished
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.6667  0.8036  0.4286  0.7500  0.5455  0.3119  0.3425
# 1       0.8667  0.8750  0.7143  1.0000  0.8333  0.7273  0.7559
# 2       0.8000  0.8929  0.5714  1.0000  0.7273  0.5872  0.6447
# 3       0.9333  1.0000  1.0000  0.8750  0.9333  0.8673  0.8750
# 4       0.8667  0.9821  0.8571  0.8571  0.8571  0.7321  0.7321
# 5       0.8571  0.9583  0.8333  0.8333  0.8333  0.7083  0.7083
# 6       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 7       0.7143  0.8125  0.5000  0.7500  0.6000  0.3913  0.4108
# 8       0.8571  0.8958  0.8333  0.8333  0.8333  0.7083  0.7083
# 9       0.9286  0.9796  0.8571  1.0000  0.9231  0.8571  0.8660
# Mean    0.8490  0.9200  0.7595  0.8899  0.8086  0.6891  0.7044
# SD      0.0953  0.0708  0.1897  0.0976  0.1374  0.2005  0.1915

# %%
 best
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100,
#                      n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)
